# %%
# Enviroment setting up
# !pip install pandas dash
# !pip install jupyter-dash
# Out:
# Requirement already satisfied: pandas in c:\users\hossein\anaconda3v2\lib\site-packages (1.1.5)
# Requirement already satisfied: dash in c:\users\hossein\anaconda3v2\lib\site-packages (2.6.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\hossein\anaconda3v2\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\hossein\anaconda3v2\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hossein\anaconda3v2\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (5.6.0)
# Requirement already satisfied: flask-compress in c:\users\hossein\anaconda3v2\lib\site-packages (from dash) (1.12)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\hossein\anaconda3v2\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\hossein\anaconda3v2\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: colorama in c:\users\hossein\anaconda3v2\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hossein\anaconda3v2\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six in c:\users\hossein\anaconda3v2\lib\site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\hossein\anaconda3v2\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: jupyter-dash in c:\users\hossein\anaconda3v2\lib\site-packages (0.4.2)
# Requirement already satisfied: ipython in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (8.2.0)
# Requirement already satisfied: flask in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: requests in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (2.27.1)
# Requirement already satisfied: dash in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (2.6.1)
# Requirement already satisfied: ansi2html in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (1.5.5)
# Requirement already satisfied: retrying in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-dash) (6.9.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash->jupyter-dash) (5.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\hossein\anaconda3v2\lib\site-packages (from dash->jupyter-dash) (1.12)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\hossein\anaconda3v2\lib\site-packages (from flask->jupyter-dash) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\hossein\anaconda3v2\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from flask->jupyter-dash) (8.0.4)
# Requirement already satisfied: colorama in c:\users\hossein\anaconda3v2\lib\site-packages (from click>=5.1->flask->jupyter-dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hossein\anaconda3v2\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: six in c:\users\hossein\anaconda3v2\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: brotli in c:\users\hossein\anaconda3v2\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipykernel->jupyter-dash) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipykernel->jupyter-dash) (5.1.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (2.11.2)
# Requirement already satisfied: backcall in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hossein\anaconda3v2\lib\site-packages (from ipython->jupyter-dash) (61.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash) (302)
# Requirement already satisfied: wcwidth in c:\users\hossein\anaconda3v2\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hossein\anaconda3v2\lib\site-packages (from requests->jupyter-dash) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hossein\anaconda3v2\lib\site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hossein\anaconda3v2\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hossein\anaconda3v2\lib\site-packages (from requests->jupyter-dash) (3.3)
# Requirement already satisfied: asttokens in c:\users\hossein\anaconda3v2\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hossein\anaconda3v2\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Requirement already satisfied: executing in c:\users\hossein\anaconda3v2\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)

# %%
# Import required libraries
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px
import wget

# %%
# Data load
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                {'label': 'All Sites', 'value': 'ALL'},
                                                {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                                {'label': 'KSC LC-39A', 'value':'KSC LC-39A'},
                                                {'label': 'VAFB SLC-4E', 'value':'VAFB SLC-4E'}
                                             ],
                                             # Default dropdown value
                                             value='ALL',
                                             placeholder="Select a launch site",
                                             searchable=True),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0',
                                                       2500: '2500',
                                                       5000: '5000',
                                                       7500: '7500'},
                                                value=[min_payload, max_payload]),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))

def render_pie_chart(entered_site):
  # Filtered dataframe for else condition
    filtered_df = spacex_df[spacex_df['Launch Site']==str(entered_site)]
    if entered_site == 'ALL':
        fig = px.pie(spacex_df, values='class', 
        names='Launch Site', 
        title='Launch in all sites')
        return fig
    else:
        fig = px.pie(filtered_df, names='class', title=f'Launch in {entered_site}')
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'), 
               Input(component_id='payload-slider', component_property='value')])

def render_scatter_plot(entered_site, slider_payload):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= slider_payload[0]) & (spacex_df['Payload Mass (kg)'] <= slider_payload[1])]
    if entered_site == 'ALL':
      fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', color='Booster Version Category', title='All site payload and outcome')
      return fig
    else:
      filtered_df = filtered_df[filtered_df['Launch Site']==entered_site]
      fig = px.scatter(filtered_df, x='Payload Mass (kg)', y = 'class', color='Booster Version Category', title=f'Site {entered_site} Payload and outcome')
      return fig

# Run the app
app.run_server(mode='inline', debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
